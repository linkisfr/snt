# %% [markdown]
# <div style="text-align:center"><h1 style="border-style:solid;border-width:1px;border-radius:5px;
#     padding:5px;margin:10px;background-color:lightgreen;box-shadow: 6px 6px 6px black; display:inline-block">Exercices d'entrainement du Chapitre 1<br> Bases du langage Python</h1></div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 1 : </strong>
# Effectuer en Python le calcul : $\frac{3^9-27}{4\times 117}$
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 2 : </strong>
# Quel et le type des expressions suivantes ?
#     <ul>
#         <li><code>13 // 5</code></li>
#         <li><code>13 / 5</code></li>
#         <li><code>13 % 5</code></li>
#         <li><code>6 / 2</code></li>
#         <li><code>6 // 2</code></li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 3 : </strong>
#     Quelle est la valeur de la variable <code>d</code> à la fin du programme suivant ?
#     <code>
#         a = 3
#         b = 5
#         c = a + b
#         b = a + c
#         d = b * c</code>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 4 : </strong>
#     Quelle est la valeur de la variable <code>a</code> à la fin du programme suivant ?
#     <code>
#         a = 2
#         a += 3
#         a *= 2
#         a *= a
#         a //= 4
#         a -= 8 </code>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 5 : </strong>
#     Ecrire un programme qui permute les valeurs des variables $a$, $b$ et $c$.<br>
#     Dans l'exemple ci-dessous, après exécution du programme, $a$ devra être égal à 4, $b$ devra être égal à 8 et $c$ devra être égal à 7.<br>
#     Votre programme doit fonctionner quelles que soient les valeurs initiales données à $a$, $b$ et $c$.
# </div>

# %%
a = 7
b = 4
c = 8

# %%
# Votre programme ici
...

print(a, b, c)

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 6 : </strong>
# Quelle est la différence entre <code>print(a)</code> et <code>print("a")</code> ?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 7 : </strong>
#     Ecrire un programme qui demande à l'utilisateur de saisir son année de naissance, et qui lui répond en affichant son âge.<br>
#     Exemple d'affichage attendu : <mark>Tu as 15 ans.</mark>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 8 : </strong>
#     Ecrire un programme qui demande à l'utilisateur de saisir les prénoms de quatre amis (en utilisant quatre instructions <code>input</code> successives), et qui affiche les quatre prénoms sur une seule ligne en les séparant par le caractère @.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 9 : </strong>
#    Le programme ci-dessous comporte plusieurs erreurs. <br>
#     Corrigez-le pour qu'il fonctionne.
# </div>

# %%
age = input("Quel est ton âge ? ")
age =+ 10
print("Dans 10 ans, tu auras","age","ans.")
# Out:
# Quel est ton âge ? 7
# Dans 10 ans, tu auras 10 ans.

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 10 : </strong> <em>La machine à sous</em><br>
#   Ecrire un programme qui simule une machine à sous : la machine doit choisir au hasard trois nombres entiers compris entre 1 et 9, et les afficher sur une seule ligne en les séparant par le caractère | (pipe) <br>
# Exemple d'affichage attendu : 8|4|5  <br>
# Remarque : on verra plus tard comment indiquer si le joueur a gagné, c'est-à-dire si 2 ou 3 chiffres sont identiques.
