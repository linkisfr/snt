# %% [markdown]
# <div style="text-align:center"><h1 style="border-style:solid;border-width:1px;border-radius:5px;
#     padding:5px;margin:10px;background-color:lightgreen;box-shadow: 6px 6px 6px black; display:inline-block">Exercices d'entrainement du Chapitre 5<br>Boucle while</h1></div>

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;">
#     <strong>Exercice 1</strong><br>
# Ecrire un programme qui demande indéfiniment à l'utilisateur de saisir une chaîne de caractères, et qui s'arrête lorsque l'utilisateur saisit "stop" ou "quitter" ou "fin".
# </div>

# %%
# Votre programme ici :

# %% [markdown]
#  <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;">
#     <strong>Exercice 2</strong> <em>Simulation d'une boucle for par une boucle while</em><br>
#     Réécrire le programme ci-dessous en utilisant une boucle <code>while</code> à la place de la boucle <code>for</code>.
# </div>

# %%
# Le programme avec une boucle for :
somme = 0
for i in range(10):
    somme = somme + i
print(somme)

# %%
# Le même programme avec une boucle while :

# %% [markdown]
#  <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;">
#     <strong>Exercice 3</strong> <em>Simulation d'une boucle while par une boucle for</em><br>
#     Réécrire le programme ci-dessous en utilisant une boucle <code>for</code> à la place de la boucle <code>while</code>.
# </div>

# %%
# Le programme avec une boucle while :
i = 0
while i < 5:
    print("HHHHH")
    i = i + 1

# %%
# Le même programme avec une boucle for :

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;"><strong>Exercice 4 </strong> <em>Exercice de Bac septembre 2024, spécialité Maths</em> <br>
# </div>

# %% [markdown]
# ![Partie%201.png](attachment:Partie%201.png)
# ![Partie%202.png](attachment:Partie%202.png)

# %%
1.

# %%
2. a.

# %%
# 2. b. Programme Python

# %%
3.

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;"><strong>Exercice 5</strong> <em>Détermination d'un seuil 1</em><br>
#    Un population de bactéries double à chaque unité de temps.<br>
#     Il y a une seule bactérie au départ.<br>
#     Ecrire un programme qui détermine au bout de combien d'unités de temps la population des bactéries dépassera les dix milliards.
#    </div>
# </div>

# %%
# Votre programme ici :

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;"><strong>Exercice 6</strong> <em>Détermination d'un seuil 2</em><br>
#    On dipose d'une certaine quantité de noyaux radioactifs. Le nombre de ces noyaux diminue de 0,1% toutes les heures.<br>
#    Ecrire un programme qui calcule au bout de combien d'heures la quantité de noyaux radioactifs aura diminué de moitié.   </div>
# </div>

# %%
# Votre programme ici :

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;"><strong>Exercice 7</strong> <em>Instruction <code>break</code></em><br>
#     Quelle est la valeur de la variable <code>somme</code> à la fin du programme ci-dessous ?
# </div>

# %% [markdown]
# ![prog7.png](attachment:prog7.png)

# %% [markdown]
# <div style="padding:10px ;border:solid 4px lightblue; border-radius: 10px; background-color:aliceblue;"><strong>Exercice 8</strong> <em>Instruction <code>continue</code></em><br>
# Quelle est la valeur de la variable <code>somme</code> à la fin du programme ci-dessous ?
# </div>

# %% [markdown]
# ![Prog%208.png](attachment:Prog%208.png)
