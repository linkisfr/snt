# %% [markdown]
# <div style="text-align:center"><h1 style="border-style:solid;border-width:1px;border-radius:5px;
#     padding:5px;margin:10px;background-color:lightgreen;box-shadow: 6px 6px 6px black; display:inline-block">Exercices d'entrainement du Chapitre 3<br> Conditions et booléens</h1></div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 1 : </strong> <br>
# 1) Ecrire un programme qui demande à l'utilisateur de saisir sa date d'anniversaire au format MM-JJ et qui affiche le message "Joyeux anniversaire!" s'il est né le 28 septembre.<br>
# 2) Améliorer votre programme pour qu'il affiche "Joyeux anniversaire!" à l'utilisateur si c'est <strong>aujourd'hui</strong> son anniversaire.<br>
# Voir ci-dessous comment accéder à la date d'aujourd'hui en Python.
# </div>

# %%
# Programme 1

# %%
# Programme 2
from datetime import date
today = str(date.today())
print("Date d'aujourd'hui : ", today)
print("Date d'aujourd'hui sans l'année : ", today[5:])
# Out:
# Date d'aujourd'hui :  2024-09-23
# Date d'aujourd'hui sans l'année :  09-23

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 2 : </strong>
# Ecrire un programme qui demande à l'utilisateur de saisir un nombre entier et qui affiche "pair" si ce nombre est pair et "impair" si ce nombre est impair.<br>
#     Indication : Utiliser <code>n % 2</code> qui renvoie le reste de la division de n par 2.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 3 : </strong> <br>
# 1) Ecrire un programme qui affiche un échiquier comme ci-dessous :<br>
#     <pre>XOXOXOXO
# OXOXOXOX
# XOXOXOXO
# OXOXOXOX
# XOXOXOXO
# OXOXOXOX
# XOXOXOXO
# OXOXOXOX
# </pre><br>
# 2) Améliorer ce programme pour qu'il demande d'abord à l'utilisateur de saisir le côté du carré.</div>
# </div>

# %%
# Programme 1

# %%
# Programme 2

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 4 : </strong>
#     <em>Nombre de jours de gel</em> <br>
# Le programme ci-dessous demande à l'utilisateur de saisir la température minimale observée lors de 7 journées consécutives.<br>
# Compléter ce programme pour qu'il affiche le nombre de jours de gel.<br>
#     Par exemple, si les valeurs saisies sont 5, 2, -3, -4, 0, 3 et -1, le programme devra afficher 4.
# </div>

# %%
# Programme à compléter
...
for i in range(1,8):
    température = int(input("Quelle est la température du jour "+str(i)+" ? "))  
    ...
       ...
...

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 5 : </strong>
#    <em>Calcul du maximum d'une liste d'entiers</em> <br>
#     Ecrire un programme qui demande à l'utilisateur le nombre de valeurs qu'il va saisir, puis qui demande de saisir les valeurs successivement, et qui affiche à la fin la plus grande des valeurs saisies.<br>
# Par exemple, l'utilisateur va saisir 4 pour le nombre de valeurs, puis saisir les valeurs 7, 9, 2 et 5. La valeur affichée sera alors 9.<br>
#     <em>L'utilisation des listes (ou tableaux) n'est pas autorisée ici.</em>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 6 : </strong>
# Entre les deux programmes ci-dessous, lequel s'exécutera le plus rapidement? Expliquez pourquoi.
# </div>

# %%
# Programme 1
n = int(input())
if fonctionCompliquée(n) <= 0:
    print('a')
if 0 < fonctionCompliquée(n) <= 15:
    print('b')
if 15 < fonctionCompliquée(n):
    print('c')

# %%
# Programme 2
n = int(input())
if fonctionCompliquée(n) <= 0:
    print('a')
elif 0 < fonctionCompliquée(n) <= 15:
    print('b')
else: 
    print('c')

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 7 : </strong>
# Voici les tarifs postaux "Lettre suivie" en 2024 :
#     <table style="border:1px solid #000000;text-align:center">
#         <tr><th style="border:1px solid #000000;text-align:center">Poids jusqu'à ...</th><th style="border:1px solid #000000;text-align:center">Tarif</th></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">20 g</td><td style="border:1px solid #000000;text-align:center">1,79 €</td></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">100 g</td><td style="border:1px solid #000000;text-align:center">3,08 €</td></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">250 g</td><td style="border:1px solid #000000;text-align:center">4,80 €</td></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">500 g</td><td style="border:1px solid #000000;text-align:center">6,80 €</td></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">1 kg</td><td style="border:1px solid #000000;text-align:center">8,20 €</td></tr>
#         <tr><td style="border:1px solid #000000;text-align:center">2 kg</td><td style="border:1px solid #000000;text-align:center">9,79 €</td></tr>
#     </table><br>
# Ecrire un programme qui demande à l'utilisateur de saisir le poids de sa lettre (en grammes), et qui affiche le tarif correspondant.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 8 : </strong><br>
# Qu'affiche le programme ci-dessous ?<br>
#   a) Si $n$ vaut 12.<br>
#   b) Si $n$ vaut 13.<br>
#   c) Si $n$ vaut 14.
# </div>

# %% [markdown]
# ![Chap3%20exo8.png](attachment:Chap3%20exo8.png)

# %%
a) 
b) 
c)

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 9 : </strong>  <em>La machine à sous (suite)</em><br>
#   Ecrire un programme qui simule une machine à sous : la machine doit choisir au hasard trois nombres entiers compris entre 1 et 9, et les afficher sur une seule ligne en les séparant par le caractère |<br>
#     Votre programme doit ensuite afficher le message "Gagné!" ou "Perdu!" selon les cas.
#     Le joueur a gagné si 2 ou 3 chiffres sont identiques. <br>
# Exemples d'affichages attendus :<br>
#     8|4|8 Gagné!<br>
#     5|1|7 Perdu!<br>
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid 1px; border-radius: 5px"><strong>Exercice 10 : </strong><em>Les nombres parfaits</em> <br>
#     Un nombre <strong>parfait</strong> est un nombre entier naturel égal à la somme de ses diviseurs (excepté lui-même).<br>
#     Par exemple, 6 est un nombre parfait car il est divisible par 1, par 2 et par 3 (et par 6 mais on ne prend pas en compte ce diviseur), et $1+2+3=6$.<br>
#     Déterminer à l'aide d'un programme tous les nombres parfaits inférieurs à 1000.<br>
#     Indication : vous devez trouver trois nombres parfaits (le plus petit d'entre eux étant 6).
# </div>
